# %%
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import seaborn as sns

# %%
attr = pd.read_csv(r"C:\Users\libin\OneDrive\Desktop\UMAV PROJECTS\PROJECT 8\Attrition data.csv")

# %%
attr
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                    6          2  Life Sciences              1  Female  ...
# 1                   10          1  Life Sciences              1  Female  ...
# 2                   17          4          Other              1    Male  ...
# 3                    2          5  Life Sciences              1    Male  ...
# 4                   10          1        Medical              1    Male  ...
# ...                ...        ...            ...            ...     ...  ...
# 4405                 5          4        Medical              1  Female  ...
# 4406                 2          4        Medical              1    Male  ...
# 4407                25          2  Life Sciences              1    Male  ...
# 4408                18          2        Medical              1    Male  ...
# 4409                28          3        Medical              1    Male  ...
#
#       TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# 0                   1.0                     6              1
# 1                   6.0                     3              5
# 2                   5.0                     2              5
# 3                  13.0                     5              8
# 4                   9.0                     2              6
# ...                 ...                   ...            ...
# 4405               10.0                     5              3
# 4406               10.0                     2              3
# 4407                5.0                     4              4
# 4408               10.0                     2              9
# 4409                NaN                     6             21
#
#       YearsSinceLastPromotion  YearsWithCurrManager EnvironmentSatisfaction  \
# 0                           0                     0                     3.0
# 1                           1                     4                     3.0
# 2                           0                     3                     2.0
# 3                           7                     5                     4.0
# 4                           0                     4                     4.0
# ...                       ...                   ...                     ...
# 4405                        0                     2                     4.0
# 4406                        0                     2                     4.0
# 4407                        1                     2                     1.0
# 4408                        7                     8                     4.0
# 4409                        3                     9                     1.0
#
#       JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0                 4.0              2.0               3                  3
# 1                 2.0              4.0               2                  4
# 2                 2.0              1.0               3                  3
# 3                 4.0              3.0               2                  3
# 4                 1.0              3.0               3                  3
# ...               ...              ...             ...                ...
# 4405              1.0              3.0               3                  3
# 4406              4.0              3.0               2                  3
# 4407              3.0              3.0               3                  4
# 4408              1.0              3.0               2                  3
# 4409              3.0              NaN               4                  3
#
# [4410 rows x 29 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
attr.shape
# Out:
# (4410, 29)

# %%
attr.isnull()
# Out:
#       EmployeeID    Age  Attrition  BusinessTravel  Department  \
# 0          False  False      False           False       False
# 1          False  False      False           False       False
# 2          False  False      False           False       False
# 3          False  False      False           False       False
# 4          False  False      False           False       False
# ...          ...    ...        ...             ...         ...
# 4405       False  False      False           False       False
# 4406       False  False      False           False       False
# 4407       False  False      False           False       False
# 4408       False  False      False           False       False
# 4409       False  False      False           False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  Gender  ...  \
# 0                False      False           False          False   False  ...
# 1                False      False           False          False   False  ...
# 2                False      False           False          False   False  ...
# 3                False      False           False          False   False  ...
# 4                False      False           False          False   False  ...
# ...                ...        ...             ...            ...     ...  ...
# 4405             False      False           False          False   False  ...
# 4406             False      False           False          False   False  ...
# 4407             False      False           False          False   False  ...
# 4408             False      False           False          False   False  ...
# 4409             False      False           False          False   False  ...
#
#       TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 False                  False           False
# 1                 False                  False           False
# 2                 False                  False           False
# 3                 False                  False           False
# 4                 False                  False           False
# ...                 ...                    ...             ...
# 4405              False                  False           False
# 4406              False                  False           False
# 4407              False                  False           False
# 4408              False                  False           False
# 4409               True                  False           False
#
#       YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# 0                       False                 False                    False
# 1                       False                 False                    False
# 2                       False                 False                    False
# 3                       False                 False                    False
# 4                       False                 False                    False
# ...                       ...                   ...                      ...
# 4405                    False                 False                    False
# 4406                    False                 False                    False
# 4407                    False                 False                    False
# 4408                    False                 False                    False
# 4409                    False                 False                    False
#
#       JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0               False            False           False              False
# 1               False            False           False              False
# 2               False            False           False              False
# 3               False            False           False              False
# 4               False            False           False              False
# ...               ...              ...             ...                ...
# 4405            False            False           False              False
# 4406            False            False           False              False
# 4407            False            False           False              False
# 4408            False            False           False              False
# 4409            False             True           False              False
#
# [4410 rows x 29 columns]

# %%
attr.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
attr.fillna(0, inplace=True)

# %%
attr.isnull().sum()
# Out:
# EmployeeID                 0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# PerformanceRating          0
# dtype: int64

# %%
attr.describe()
# Out:
#         EmployeeID          Age  DistanceFromHome    Education  EmployeeCount  \
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0
# mean   2205.500000    36.923810          9.192517     2.912925            1.0
# std    1273.201673     9.133301          8.105026     1.023933            0.0
# min       1.000000    18.000000          1.000000     1.000000            1.0
# 25%    1103.250000    30.000000          2.000000     2.000000            1.0
# 50%    2205.500000    36.000000          7.000000     3.000000            1.0
# 75%    3307.750000    43.000000         14.000000     4.000000            1.0
# max    4410.000000    60.000000         29.000000     5.000000            1.0
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4410.000000        4410.000000
# mean      2.063946   65029.312925            2.683220          15.209524
# std       1.106689   47068.888559            2.499737           3.659108
# min       1.000000   10090.000000            0.000000          11.000000
# 25%       1.000000   29110.000000            1.000000          12.000000
# 50%       2.000000   49190.000000            2.000000          14.000000
# 75%       3.000000   83800.000000            4.000000          18.000000
# max       5.000000  199990.000000            9.000000          25.000000
#
#        StandardHours  ...  TotalWorkingYears  TrainingTimesLastYear  \
# count         4410.0  ...        4410.000000            4410.000000
# mean             8.0  ...          11.256916               2.799320
# std              0.0  ...           7.790928               1.288978
# min              8.0  ...           0.000000               0.000000
# 25%              8.0  ...           6.000000               2.000000
# 50%              8.0  ...          10.000000               3.000000
# 75%              8.0  ...          15.000000               3.000000
# max              8.0  ...          40.000000               6.000000
#
#        YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  \
# count     4410.000000              4410.000000           4410.000000
# mean         7.008163                 2.187755              4.123129
# std          6.125135                 3.221699              3.567327
# min          0.000000                 0.000000              0.000000
# 25%          3.000000                 0.000000              2.000000
# 50%          5.000000                 1.000000              3.000000
# 75%          9.000000                 3.000000              7.000000
# max         40.000000                15.000000             17.000000
#
#        EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# count              4410.000000      4410.000000      4410.000000
# mean                  2.708163         2.715873         2.737642
# std                   1.108679         1.113943         0.748091
# min                   0.000000         0.000000         0.000000
# 25%                   2.000000         2.000000         2.000000
# 50%                   3.000000         3.000000         3.000000
# 75%                   4.000000         4.000000         3.000000
# max                   4.000000         4.000000         4.000000
#
#        JobInvolvement  PerformanceRating
# count     4410.000000        4410.000000
# mean         2.729932           3.153741
# std          0.711400           0.360742
# min          1.000000           3.000000
# 25%          2.000000           3.000000
# 50%          3.000000           3.000000
# 75%          3.000000           3.000000
# max          4.000000           4.000000
#
# [8 rows x 21 columns]

# %%
num = attr.select_dtypes(include=np.number).columns
len(num)
# Out:
# 21

# %%
for i in num:
    print("The no.of unique values in",i,"are: ",attr.loc[:,i].nunique())
# Out:
# The no.of unique values in EmployeeID are:  4410
# The no.of unique values in Age are:  43
# The no.of unique values in DistanceFromHome are:  29
# The no.of unique values in Education are:  5
# The no.of unique values in EmployeeCount are:  1
# The no.of unique values in JobLevel are:  5
# The no.of unique values in MonthlyIncome are:  1349
# The no.of unique values in NumCompaniesWorked are:  10
# The no.of unique values in PercentSalaryHike are:  15
# The no.of unique values in StandardHours are:  1
# The no.of unique values in StockOptionLevel are:  4
# The no.of unique values in TotalWorkingYears are:  40
# The no.of unique values in TrainingTimesLastYear are:  7
# The no.of unique values in YearsAtCompany are:  37
# The no.of unique values in YearsSinceLastPromotion are:  16
# The no.of unique values in YearsWithCurrManager are:  18
# The no.of unique values in EnvironmentSatisfaction are:  5
# The no.of unique values in JobSatisfaction are:  5
# The no.of unique values in WorkLifeBalance are:  5
# The no.of unique values in JobInvolvement are:  4
# The no.of unique values in PerformanceRating are:  2

# %% [markdown]
# # Column Description

# %% [markdown]
# Independent Variables were:
#
# Employee ID : Unique Id given to the Employee by the Organization
# Age : Age of Employees
# Business Travel : 1-Travel_Rraely  2-Travel_Frequently  3-Non_Travel
# Department : 1-Sales   2-Research & Development  3-Human Resources
# Distance from Home
# Education : 1 , 2 , 3 , 4 , 5
#
# Education Field : 1-Life Sciences  2-Medical 3-Marketing 4-Technical Degree 5-Human Resources 6-Other
#
# Employee Count : 1
# Gender : Male or Female
# Job Level : 1 , 2 , 3 , 4 , 5
#
# Job Role : 1-Healthcare Representative 2-Research Scientist 3-Sales Executive 4-Human Resources 5-Research Director 6-Laboratory Technician 7-Manufacturing Director 8-Sales Representative 9-Manager
#
# Marital Status : 1-Married 2-Single 3-Divorced
# Number of Companies Worked : 1, 0, 3, 4, 2, 7, 9, 5, 6, 8
# Over 18 : Y or N
#
# Dependent Variables were:
#
# Attrition : Yes or No
# Percent of Salary Hike
# Standard Hours : 8
# Stock Option Level : 0 , 1 , 2 , 3
# Total Working Years
# Training Times Last Year
# Years At Company
# Years Since Last Promotion
# Years With Current Manager
# Environment Satisfaction : 0 , 1 , 2 , 3 , 4
# Job Satisfaction : 0 , 1 , 2 , 3 , 4
# Work Life Balance : 0 , 1 , 2 , 3 , 4
# Job Involvement : 1 , 2 , 3 , 4
# Performance Rating : 3 or 4

# %% [markdown]
# # Top 5 values

# %%
attr.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# 0                1.0                     6              1
# 1                6.0                     3              5
# 2                5.0                     2              5
# 3               13.0                     5              8
# 4                9.0                     2              6
#
#    YearsSinceLastPromotion  YearsWithCurrManager EnvironmentSatisfaction  \
# 0                        0                     0                     3.0
# 1                        1                     4                     3.0
# 2                        0                     3                     2.0
# 3                        7                     5                     4.0
# 4                        0                     4                     4.0
#
#    JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0              4.0              2.0               3                  3
# 1              2.0              4.0               2                  4
# 2              2.0              1.0               3                  3
# 3              4.0              3.0               2                  3
# 4              1.0              3.0               3                  3
#
# [5 rows x 29 columns]

# %% [markdown]
# # Bottom 5 values

# %%
attr.tail()
# Out:
#       EmployeeID  Age Attrition BusinessTravel              Department  \
# 4405        4406   42        No  Travel_Rarely  Research & Development
# 4406        4407   29        No  Travel_Rarely  Research & Development
# 4407        4408   25        No  Travel_Rarely  Research & Development
# 4408        4409   42        No  Travel_Rarely                   Sales
# 4409        4410   40        No  Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 4405                 5          4        Medical              1  Female  ...
# 4406                 2          4        Medical              1    Male  ...
# 4407                25          2  Life Sciences              1    Male  ...
# 4408                18          2        Medical              1    Male  ...
# 4409                28          3        Medical              1    Male  ...
#
#       TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# 4405               10.0                     5              3
# 4406               10.0                     2              3
# 4407                5.0                     4              4
# 4408               10.0                     2              9
# 4409                0.0                     6             21
#
#       YearsSinceLastPromotion  YearsWithCurrManager EnvironmentSatisfaction  \
# 4405                        0                     2                     4.0
# 4406                        0                     2                     4.0
# 4407                        1                     2                     1.0
# 4408                        7                     8                     4.0
# 4409                        3                     9                     1.0
#
#       JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 4405              1.0              3.0               3                  3
# 4406              4.0              3.0               2                  3
# 4407              3.0              3.0               3                  4
# 4408              1.0              3.0               2                  3
# 4409              3.0              0.0               4                  3
#
# [5 rows x 29 columns]

# %% [markdown]
# # Finding Duplicate Values

# %%
attr.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %% [markdown]
# # Count of duplicate values

# %%
attr.duplicated().value_counts()
# Out:
# False    4410
# Name: count, dtype: int64

# %% [markdown]
# There are No Duplicate Columns

# %% [markdown]
# # Unique values of every columns

# %%
attr.nunique()
# Out:
# EmployeeID                 4410
# Age                          43
# Attrition                     2
# BusinessTravel                3
# Department                    3
# DistanceFromHome             29
# Education                     5
# EducationField                6
# EmployeeCount                 1
# Gender                        2
# JobLevel                      5
# JobRole                       9
# MaritalStatus                 3
# MonthlyIncome              1349
# NumCompaniesWorked           10
# Over18                        1
# PercentSalaryHike            15
# StandardHours                 1
# StockOptionLevel              4
# TotalWorkingYears            40
# TrainingTimesLastYear         7
# YearsAtCompany               37
# YearsSinceLastPromotion      16
# YearsWithCurrManager         18
# EnvironmentSatisfaction       5
# JobSatisfaction               5
# WorkLifeBalance               5
# JobInvolvement                4
# PerformanceRating             2
# dtype: int64

# %% [markdown]
# # Data Insights

# %% [markdown]
# In the given dataset, we have two types of employee one who stayed and another who left the company.

# %% [markdown]
# # Attrition

# %%
att_count=pd.DataFrame(attr["Attrition"].value_counts())
att_count
# Out:
#            count
# Attrition
# No          3699
# Yes          711

# %% [markdown]
# # Distribution of Attrition

# %%
attr['Attrition'].value_counts().plot(kind='pie', labels=['No','Yes'],autopct='%.1f%%',figsize=(12,4), fontsize=13)
plt.show()

# %%
attr['Attrition'].value_counts().plot(kind='barh', figsize=(12,4), color="coral", fontsize=13)

plt.xlabel("Count of people", fontsize=12)
plt.ylabel("Attrition", fontsize=12)
plt.title("Attrition of the employees", fontsize=16)
plt.show()

# %% [markdown]
# # Age and Attrition

# %%
#Number of Unique values

attr["Age"].nunique()
# Out:
# 43

# %%
attr.hist(column="Age",
         grid=False,
         figsize=(6,4),
         color="crimson",
         edgecolor="black",
         bins=12)

plt.xlabel("Age values",fontsize=12)
plt.ylabel("frequency of emp",fontsize=12)
plt.title("Histogram of Age",fontsize=16)

plt.show()

# %% [markdown]
# Most of the employees, who have been a part of the company, tend to fall in the age range from 25 years to 45 years. (68–95–99 rule)

# %%
attr['Age'].value_counts().plot(kind='bar', figsize=(15,4), color="blue", fontsize=13)

plt.xlabel("Age groups", fontsize=12)
plt.ylabel("Count of people", fontsize=12)
plt.title("Age of the employees", fontsize=16)
plt.show()

# %% [markdown]
# Maximum employees age lies in the range of 30 to 40

# %%
t = pd.crosstab(attr.Age,columns = attr.Attrition)
t
# Out:
# Attrition   No  Yes
# Age
# 18          12   12
# 19           9   18
# 20          15   18
# 21          21   18
# 22          33   15
# 23          30   12
# 24          57   21
# 25          60   18
# 26          81   36
# 27         135    9
# 28         102   42
# 29         150   54
# 30         153   27
# 31         153   54
# 32         150   33
# 33         138   36
# 34         204   27
# 35         204   30
# 36         189   18
# 37         132   18
# 38         168    6
# 39         108   18
# 40         156   15
# 41         102   18
# 42         132    6
# 43          90    6
# 44          81   18
# 45         117    6
# 46          87   12
# 47          63    9
# 48          51    6
# 49          66    6
# 50          75   15
# 51          51    6
# 52          45    9
# 53          51    6
# 54          54    0
# 55          57    9
# 56          33    9
# 57          12    0
# 58          27   15
# 59          30    0
# 60          15    0

# %% [markdown]
# # What age group is more likely to leave?

# %%
plt.subplots (figsize=(15,4))
sns.countplot (x='Age',  hue='Attrition', data= attr, palette = 'colorblind')
plt.show()

# %% [markdown]
# The proportion of employees who left was comparatively less among the senior level employees. Maybe these employees were at a higher authority and were less likely to leave that position.
#
# Major Attrition occured among the mid-career level employees. Career change and career growth could be one of the possibilities for such an attrition levels.

# %%
attr.boxplot(column = 'Age', by = 'Attrition', vert= False)
plt.show()

# %% [markdown]
# we can express that Age does not play a powerful role in influencing attrition but In the above plot we can see that affirmative attrition count is higher in late 20 and early 30s.

# %% [markdown]
# # Monthly Income

# %%
attr.MonthlyIncome.describe()
# Out:
# count      4410.000000
# mean      65029.312925
# std       47068.888559
# min       10090.000000
# 25%       29110.000000
# 50%       49190.000000
# 75%       83800.000000
# max      199990.000000
# Name: MonthlyIncome, dtype: float64

# %%
attr["MonthlyIncome"].nunique()
# Out:
# 1349

# %%
sns.distplot(attr['MonthlyIncome']) 
plt.show()

# %% [markdown]
# This variable is left skewed distribution,meaning most of its values are located at the lower end(2000-6000)

# %%
p_attr = attr.loc[attr['Attrition'] == "Yes"]
n_attr = attr.loc[attr['Attrition'] == "No"]

# %%
sns.distplot(n_attr['MonthlyIncome'], label='Negative attrition')
sns.distplot(p_attr['MonthlyIncome'], label='positive attrition')
plt.show()

# %% [markdown]
# There is high attrition rate among employees of relatively lower salary range, ie. less than 5000.

# %%
sns.catplot(x="Attrition",y="MonthlyIncome",kind="box",data=attr)   
plt.title("Box plot grouped by Attrition")
plt.show()

# %% [markdown]
# There is high attrition rate among employees of relatively lower salary range, ie. less than 5000.

# %%
sns.catplot(x="MaritalStatus",y="MonthlyIncome",hue="Attrition" ,kind="boxen",data=attr)   ##box graph
plt.show()

# %% [markdown]
# This will show monthly income and attrition using Marital Status category

# %%
attr.plot.scatter(x = 'MonthlyIncome', y = 'Age',
                  color = 'brown', title = 'MonthlyIncome vs Age')
plt.show()

# %%
sns.violinplot(x ="JobSatisfaction", y ="MonthlyIncome", hue ="Attrition",
data = attr, split = True)
plt.show()

# %% [markdown]
# # Job Satisfaction

# %%
#Number of Unique values
attr["JobSatisfaction"].unique().size
# Out:
# 5

# %%
attr["JobSatisfaction"].value_counts()
# Out:
# JobSatisfaction
# 4.0    1367
# 3.0    1323
# 1.0     860
# 2.0     840
# 0.0      20
# Name: count, dtype: int64

# %% [markdown]
# # Department

# %%
attr["Department"].value_counts()
# Out:
# Department
# Research & Development    2883
# Sales                     1338
# Human Resources            189
# Name: count, dtype: int64

# %% [markdown]
# # Plot of different department

# %%
labels = ['Research & Development', 'Sales', 'Human Resources']
plt.pie(attr.Department.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %%
t3 = pd.crosstab(attr.Department,columns = attr.Attrition)
t3
# Out:
# Attrition                 No  Yes
# Department
# Human Resources          132   57
# Research & Development  2430  453
# Sales                   1137  201

# %% [markdown]
# # Replace Attrition to numeric values

# %%
attr = attr.replace("Yes", 1)
attr = attr.replace("No", 0)

# %%
attr.groupby('Department')['Attrition'].mean()
# Out:
# Department
# Human Resources           0.301587
# Research & Development    0.157128
# Sales                     0.150224
# Name: Attrition, dtype: float64

# %%
sns.catplot(x="Department",y="Attrition" ,hue="MaritalStatus",kind="bar",data=attr) 
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Employees in R&D department seem to have less attrition rate among other department employees, with higher attrition in both Human Resources and Sales Department.

# %%
sns.catplot(x="Department",y="Attrition" ,col="MaritalStatus",kind="bar",data=attr)   
plt.show()

# %% [markdown]
# when drilled down by Marital status, sales singles seem to have almost twice the attrition rate of sales married employees.

# %% [markdown]
# # Categorical plot between MonthlyIncome and Department and Attrition

# %%
sns.catplot(x="Department",y="MonthlyIncome" ,hue="Attrition",kind="box",data=attr)   
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Here shows less income employee from human resorce has more Attrition

# %%
sns.catplot(x="Department",y="Age" ,kind="box",data=attr)   
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# It shows relation between departments and age which normally distributed

# %%
tab=pd.crosstab(attr["Department"],attr["Attrition"],normalize='index')*100

tab.plot(kind="bar")
plt.show()


print(tab)
# Out:
# Attrition                       0          1
# Department
# Human Resources         69.841270  30.158730
# Research & Development  84.287201  15.712799
# Sales                   84.977578  15.022422

# %% [markdown]
# # Education Field

# %%
#Number of Unique values
attr["EducationField"].nunique()
# Out:
# 6

# %%
attr["EducationField"].value_counts()
# Out:
# EducationField
# Life Sciences       1818
# Medical             1392
# Marketing            477
# Technical Degree     396
# Other                246
# Human Resources       81
# Name: count, dtype: int64

# %%
attr["EducationField"].value_counts().plot(kind="barh",figsize=(8,4),fontsize=13)
plt.show()

# %%
labels = ['Life Sciences', 'Medical', 'Marketing','Technical Degree','Other','Human Resources']
plt.pie(attr.EducationField.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %%
t4 = pd.crosstab(attr.EducationField,columns = attr.Attrition)
t4
# Out:
# Attrition            0    1
# EducationField
# Human Resources     48   33
# Life Sciences     1515  303
# Marketing          402   75
# Medical           1167  225
# Other              216   30
# Technical Degree   351   45

# %%
tab=pd.crosstab(attr["EducationField"],attr["Attrition"],normalize='index')*100

tab.plot(kind="bar")
plt.show()


print(tab)
# Out:
# Attrition                 0          1
# EducationField
# Human Resources   59.259259  40.740741
# Life Sciences     83.333333  16.666667
# Marketing         84.276730  15.723270
# Medical           83.836207  16.163793
# Other             87.804878  12.195122
# Technical Degree  88.636364  11.363636

# %% [markdown]
# # Can low salary be one of the reasons?

# %%
attr.groupby('EducationField').MonthlyIncome.mean()
# Out:
# EducationField
# Human Resources     60452.962963
# Life Sciences       65311.831683
# Marketing           59030.880503
# Medical             67096.724138
# Other               65761.463415
# Technical Degree    64171.666667
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# No,because even though the salary of HR and marketing employees is higher, their leaving rate is highest.

# %%
sns.violinplot(x ="EducationField", y ="MonthlyIncome", hue ="Attrition",
data = attr, split = True)
plt.show()

# %% [markdown]
# # Subplot

# %%
sns.relplot(x="Age",y="MonthlyIncome",hue="Attrition",col="MaritalStatus",data=attr)   ##subplot
plt.show()

# %% [markdown]
# # Environmental Satisfaction

# %%
#Number of Unique values
attr["EnvironmentSatisfaction"].value_counts()
# Out:
# EnvironmentSatisfaction
# 3.0    1350
# 4.0    1334
# 2.0     856
# 1.0     845
# 0.0      25
# Name: count, dtype: int64

# %%
attr["EnvironmentSatisfaction"].value_counts().plot(kind="bar",figsize=(4,6),fontsize=13)
plt.xlabel("EnvironmentSatisfaction", fontsize=12)
plt.ylabel("Count of employees", fontsize=12)
plt.title("Bar plot on category EnvironmentSatisfaction", fontsize=16)
plt.show()

# %%
t5 = pd.crosstab(attr.EnvironmentSatisfaction,columns = attr.Attrition)
t5
# Out:
# Attrition                   0    1
# EnvironmentSatisfaction
# 0.0                        20    5
# 1.0                       632  213
# 2.0                       728  128
# 3.0                      1164  186
# 4.0                      1155  179

# %% [markdown]
# # percentage of EnvironmentSatisfaction numbers using attrition

# %%
tab = pd.crosstab(attr["EnvironmentSatisfaction"],attr["Attrition"],normalize='index')*100
print(tab)
tab.plot(kind='bar')
plt.show()
# Out:
# Attrition                        0          1
# EnvironmentSatisfaction
# 0.0                      80.000000  20.000000
# 1.0                      74.792899  25.207101
# 2.0                      85.046729  14.953271
# 3.0                      86.222222  13.777778
# 4.0                      86.581709  13.418291

# %% [markdown]
# Here, we can see that people with low environmental score of 1 have higher attrition rate(25%) than the average attrition rate of 16%

# %%
plt.subplots (figsize=(22,8))
sns.countplot (x='Age',  hue='EnvironmentSatisfaction', data= attr, palette = 'colorblind')
plt.show()

# %%
sns.relplot(x="EnvironmentSatisfaction",y="MonthlyIncome",hue="Attrition",kind="line",data=attr)
plt.show()

# %% [markdown]
# # MaritalStatus

# %%
attr["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Married     2019
# Single      1410
# Divorced     981
# Name: count, dtype: int64

# %% [markdown]
# # Who is leaving more? married ,un-married or divorced employees?

# %%
labels = ['Married', 'Single','Divorced']
plt.pie(attr.MaritalStatus.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %%
attr['MaritalStatus'].value_counts().plot(kind='barh', figsize=(6,4), color="green", fontsize=13)

plt.xlabel("Count of people", fontsize=12)
plt.ylabel("MaritalStatus", fontsize=12)

plt.show()

# %%
attr.groupby('MaritalStatus').Attrition.mean()
# Out:
# MaritalStatus
# Divorced    0.100917
# Married     0.124814
# Single      0.255319
# Name: Attrition, dtype: float64

# %% [markdown]
# Singles tend to have a little higher attrition rate than others.

# %%
tab = pd.crosstab(attr["MaritalStatus"],attr["Attrition"],normalize='index')*100

tab.plot(kind='bar')
plt.show()

# %% [markdown]
# Single employee has high attrition rate(25%) compared to average attrition rate of 16%.Similarly, divorced employees have low attrition rate(10%) compared to the average of 16%.

# %% [markdown]
# # WorkLifeBalance

# %%
attr["WorkLifeBalance"].value_counts()
# Out:
# WorkLifeBalance
# 3.0    2660
# 2.0    1019
# 4.0     454
# 1.0     239
# 0.0      38
# Name: count, dtype: int64

# %%
tab = pd.crosstab(attr["WorkLifeBalance"],attr["Attrition"],normalize='index')*100

tab.plot(kind='bar')
plt.show()

# %% [markdown]
# People with work life balance of 1 have high attrition rate(31%) compared to the population attrition rate of 16%.
# Hence poor work life balance increases attrition.

# %% [markdown]
# # Years At Company

# %%
attr.YearsAtCompany.describe()
# Out:
# count    4410.000000
# mean        7.008163
# std         6.125135
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %% [markdown]
# # Are Employees leaving after working for certain number years?

# %%
attr['YearsAtCompany'].value_counts().plot(kind='bar', figsize=(19,4), color="coral", fontsize=13)

plt.xlabel("Years At Company", fontsize=12)
plt.ylabel("Count of Employees", fontsize=12)
plt.show()

# %%
plt.subplots (figsize=(22,8))
sns.countplot (x='YearsAtCompany',  hue='Attrition', data= attr, palette = 'colorblind')
plt.show()

# %% [markdown]
# Employees who have worked for less number of years tend to leave more.

# %% [markdown]
# # Distance From Home

# %%
attr.DistanceFromHome.describe()
# Out:
# count    4410.000000
# mean        9.192517
# std         8.105026
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
attr.hist(column="DistanceFromHome",
         grid=False,
         figsize=(6,4),
         color="orange",
         edgecolor="black",
         bins=10)

plt.xlabel("Distance From Home",fontsize=12)
plt.ylabel("Frequency",fontsize=12)
plt.title(" Employee 'Distance From Home' Analysis ",fontsize=16)

plt.show()

# %%
attr['DistanceFromHome'].value_counts().plot(kind='bar', figsize=(10,6), color="coral", fontsize=13)

plt.xlabel("Distance From Home", fontsize=12)
plt.ylabel("Count of Employees", fontsize=12)
plt.title(" Employee 'Distance From Home' Analysis ", fontsize=16)
plt.show()

# %% [markdown]
# This graph shows most of the employees prefer to live colser to their home.

# %%
sns.boxplot(x = "DistanceFromHome",y= "Age",data = attr, palette = "autumn_r")
plt.gcf().set_size_inches(8, 6)

# %% [markdown]
# This box plot shows DistanceFromHome with respect to age.It does not show any difference so it is normally distributed.

# %%
attr.groupby(['Age','Attrition'])['DistanceFromHome'].size().unstack().plot(kind='bar', figsize=(12,6),stacked=True)
plt.show()

# %% [markdown]
# # Relation plot between Monthly Income and Age by Marital status

# %%
sns.relplot(x="MonthlyIncome",y="Age",hue="MaritalStatus",data=attr)   
plt.show()

# %% [markdown]
# # Relation between employee's YearsAtCompany and their age with attrition

# %%
sns.relplot(x="YearsAtCompany",y="Age",hue="Attrition",col="MaritalStatus",data=attr) ##diffrnt colm with diffn class
plt.show()

# %%
sns.pairplot(attr, vars=["YearsAtCompany","Age","MonthlyIncome"])
plt.show()

# %% [markdown]
# Here pair plot pairwise relationships in attrition dataset so that here all variables in attr will be plotted against each other variable in the dataset.

# %% [markdown]
# # Correlation

# %%
num_col = attr.select_dtypes(include=np.number)

# %%
num_col.cov()
# Out:
#                            EmployeeID           Age   Attrition  \
# EmployeeID               1.621042e+06    100.573146   -2.214448
# Age                      1.005731e+02     83.417192   -0.534776
# Attrition               -2.214448e+00     -0.534776    0.135262
# DistanceFromHome        -1.131651e+01      0.515465   -0.029004
# Education               -1.261919e+01     -0.333921   -0.005691
# EmployeeCount            0.000000e+00      0.000000    0.000000
# JobLevel                -4.653436e+00     -0.029148   -0.004188
# MonthlyIncome            4.397308e+05 -19050.304118 -539.691878
# NumCompaniesWorked       4.571331e-01      6.833196    0.038156
# PercentSalaryHike       -2.076185e+01     -1.107417    0.043781
# StandardHours            0.000000e+00      0.000000    0.000000
# StockOptionLevel        -1.546031e+01     -0.247053   -0.002143
# TotalWorkingYears       -1.375709e+00     48.275419   -0.487790
# TrainingTimesLastYear   -1.672454e+01     -0.321485   -0.023433
# YearsAtCompany           3.186437e+01     17.415455   -0.302745
# YearsSinceLastPromotion  1.050578e+00      6.370852   -0.039123
# YearsWithCurrManager     3.896428e+01      6.584344   -0.204932
# EnvironmentSatisfaction  5.747448e+00      0.136753   -0.041394
# JobSatisfaction         -1.840894e+00     -0.038663   -0.040142
# WorkLifeBalance          3.107621e+00     -0.184884   -0.014848
# JobInvolvement           7.781016e+00      0.118226   -0.004078
# PerformanceRating       -3.165344e+00     -0.084224    0.003105
#
#                          DistanceFromHome   Education  EmployeeCount  \
# EmployeeID                     -11.316512  -12.619188            0.0
# Age                              0.515465   -0.333921            0.0
# Attrition                       -0.029004   -0.005691            0.0
# DistanceFromHome                65.691439   -0.071688            0.0
# Education                       -0.071688    1.048438            0.0
# EmployeeCount                    0.000000    0.000000            0.0
# JobLevel                        -0.334836    0.051838            0.0
# MonthlyIncome                -8242.961368  308.935397            0.0
# NumCompaniesWorked              -0.255626   -0.041198            0.0
# PercentSalaryHike                1.130668   -0.151858            0.0
# StandardHours                    0.000000    0.000000            0.0
# StockOptionLevel                 0.077115    0.001100            0.0
# TotalWorkingYears                0.563592   -0.092389            0.0
# TrainingTimesLastYear           -0.094040    0.013821            0.0
# YearsAtCompany                   1.572935    0.038134            0.0
# YearsSinceLastPromotion          0.059786    0.074189            0.0
# YearsWithCurrManager             0.624056    0.019569            0.0
# EnvironmentSatisfaction          0.176859   -0.046964            0.0
# JobSatisfaction                 -0.090446    0.000430            0.0
# WorkLifeBalance                  0.022396   -0.011056            0.0
# JobInvolvement                  -0.010595   -0.013315            0.0
# PerformanceRating                0.106481   -0.013147            0.0
#
#                             JobLevel  MonthlyIncome  NumCompaniesWorked  \
# EmployeeID                 -4.653436   4.397308e+05            0.457133
# Age                        -0.029148  -1.905030e+04            6.833196
# Attrition                  -0.004188  -5.396919e+02            0.038156
# DistanceFromHome           -0.334836  -8.242961e+03           -0.255626
# Education                   0.051838   3.089354e+02           -0.041198
# EmployeeCount               0.000000   0.000000e+00            0.000000
# JobLevel                    1.224760   2.464705e+03           -0.030090
# MonthlyIncome            2464.704866   2.215480e+09        -2343.236526
# NumCompaniesWorked         -0.030090  -2.343237e+03            6.248686
# PercentSalaryHike           0.044435   7.448435e+02            0.289795
# StandardHours               0.000000   0.000000e+00            0.000000
# StockOptionLevel            0.000936   1.079811e+03            0.037661
# TotalWorkingYears          -0.306067  -1.235590e+04            4.624838
# TrainingTimesLastYear      -0.046362   3.040354e+03           -0.103504
# YearsAtCompany             -0.435315   2.868462e+02           -1.781038
# YearsSinceLastPromotion    -0.216817   9.889970e+03           -0.285259
# YearsWithCurrManager       -0.218127   4.080928e+03           -0.965069
# EnvironmentSatisfaction    -0.027830  -4.241652e+02            0.028874
# JobSatisfaction            -0.017663   4.370694e+02           -0.158522
# WorkLifeBalance            -0.019282   5.867431e+01           -0.010550
# JobInvolvement             -0.009943   7.817264e+02            0.050060
# PerformanceRating          -0.000988   2.732628e+02            0.017187
#
#                          PercentSalaryHike  ...  TotalWorkingYears  \
# EmployeeID                      -20.761851  ...          -1.375709
# Age                              -1.107417  ...          48.275419
# Attrition                         0.043781  ...          -0.487790
# DistanceFromHome                  1.130668  ...           0.563592
# Education                        -0.151858  ...          -0.092389
# EmployeeCount                     0.000000  ...           0.000000
# JobLevel                          0.044435  ...          -0.306067
# MonthlyIncome                   744.843470  ...      -12355.895111
# NumCompaniesWorked                0.289795  ...           4.624838
# PercentSalaryHike                13.389068  ...          -0.555770
# StandardHours                     0.000000  ...           0.000000
# StockOptionLevel                  0.039115  ...           0.020761
# TotalWorkingYears                -0.555770  ...          60.698552
# TrainingTimesLastYear            -0.176360  ...          -0.420193
# YearsAtCompany                   -0.665807  ...          29.799898
# YearsSinceLastPromotion          -0.348262  ...          10.125487
# YearsWithCurrManager             -0.533402  ...          12.711385
# EnvironmentSatisfaction           0.002871  ...          -0.002120
# JobSatisfaction                   0.128722  ...          -0.164455
# WorkLifeBalance                  -0.106505  ...          -0.008335
# JobInvolvement                   -0.012125  ...           0.041049
# PerformanceRating                 1.021080  ...          -0.005486
#
#                          TrainingTimesLastYear  YearsAtCompany  \
# EmployeeID                          -16.724541       31.864368
# Age                                  -0.321485       17.415455
# Attrition                            -0.023433       -0.302745
# DistanceFromHome                     -0.094040        1.572935
# Education                             0.013821        0.038134
# EmployeeCount                         0.000000        0.000000
# JobLevel                             -0.046362       -0.435315
# MonthlyIncome                      3040.354261      286.846163
# NumCompaniesWorked                   -0.103504       -1.781038
# PercentSalaryHike                    -0.176360       -0.665807
# StandardHours                         0.000000        0.000000
# StockOptionLevel                     -0.076756        0.041148
# TotalWorkingYears                    -0.420193       29.799898
# TrainingTimesLastYear                 1.661465       -0.062322
# YearsAtCompany                       -0.062322       37.517284
# YearsSinceLastPromotion               0.066946       12.203275
# YearsWithCurrManager                 -0.061019       16.807568
# EnvironmentSatisfaction               0.026474        0.023930
# JobSatisfaction                      -0.029815       -0.018773
# WorkLifeBalance                      -0.023404        0.079030
# JobInvolvement                       -0.009301        0.036226
# PerformanceRating                    -0.010646       -0.024390
#
#                          YearsSinceLastPromotion  YearsWithCurrManager  \
# EmployeeID                              1.050578             38.964278
# Age                                     6.370852              6.584344
# Attrition                              -0.039123             -0.204932
# DistanceFromHome                        0.059786              0.624056
# Education                               0.074189              0.019569
# EmployeeCount                           0.000000              0.000000
# JobLevel                               -0.216817             -0.218127
# MonthlyIncome                        9889.970265           4080.928347
# NumCompaniesWorked                     -0.285259             -0.965069
# PercentSalaryHike                      -0.348262             -0.533402
# StandardHours                           0.000000              0.000000
# StockOptionLevel                        0.052318              0.053963
# TotalWorkingYears                      10.125487             12.711385
# TrainingTimesLastYear                   0.066946             -0.061019
# YearsAtCompany                         12.203275             16.807568
# YearsSinceLastPromotion                10.379347              5.863926
# YearsWithCurrManager                    5.863926             12.725820
# EnvironmentSatisfaction                 0.057074             -0.015317
# JobSatisfaction                        -0.061180             -0.091567
# WorkLifeBalance                         0.015929              0.020290
# JobInvolvement                          0.058203             -0.003482
# PerformanceRating                      -0.023429             -0.012130
#
#                          EnvironmentSatisfaction  JobSatisfaction  \
# EmployeeID                              5.747448        -1.840894
# Age                                     0.136753        -0.038663
# Attrition                              -0.041394        -0.040142
# DistanceFromHome                        0.176859        -0.090446
# Education                              -0.046964         0.000430
# EmployeeCount                           0.000000         0.000000
# JobLevel                               -0.027830        -0.017663
# MonthlyIncome                        -424.165177       437.069425
# NumCompaniesWorked                      0.028874        -0.158522
# PercentSalaryHike                       0.002871         0.128722
# StandardHours                           0.000000         0.000000
# StockOptionLevel                       -0.001878         0.037816
# TotalWorkingYears                      -0.002120        -0.164455
# TrainingTimesLastYear                   0.026474        -0.029815
# YearsAtCompany                          0.023930        -0.018773
# YearsSinceLastPromotion                 0.057074        -0.061180
# YearsWithCurrManager                   -0.015317        -0.091567
# EnvironmentSatisfaction                 1.229169        -0.013761
# JobSatisfaction                        -0.013761         1.240868
# WorkLifeBalance                         0.021625        -0.018765
# JobInvolvement                          0.011436         0.003539
# PerformanceRating                       0.005413         0.017155
#
#                          WorkLifeBalance  JobInvolvement  PerformanceRating
# EmployeeID                      3.107621        7.781016          -3.165344
# Age                            -0.184884        0.118226          -0.084224
# Attrition                      -0.014848       -0.004078           0.003105
# DistanceFromHome                0.022396       -0.010595           0.106481
# Education                      -0.011056       -0.013315          -0.013147
# EmployeeCount                   0.000000        0.000000           0.000000
# JobLevel                       -0.019282       -0.009943          -0.000988
# MonthlyIncome                  58.674315      781.726399         273.262834
# NumCompaniesWorked             -0.010550        0.050060           0.017187
# PercentSalaryHike              -0.106505       -0.012125           1.021080
# StandardHours                   0.000000        0.000000           0.000000
# StockOptionLevel               -0.014172        0.006239          -0.011170
# TotalWorkingYears              -0.008335        0.041049          -0.005486
# TrainingTimesLastYear          -0.023404       -0.009301          -0.010646
# YearsAtCompany                  0.079030        0.036226          -0.024390
# YearsSinceLastPromotion         0.015929        0.058203          -0.023429
# YearsWithCurrManager            0.020290       -0.003482          -0.012130
# EnvironmentSatisfaction         0.021625        0.011436           0.005413
# JobSatisfaction                -0.018765        0.003539           0.017155
# WorkLifeBalance                 0.559640       -0.014849          -0.005924
# JobInvolvement                 -0.014849        0.506090           0.002746
# PerformanceRating              -0.005924        0.002746           0.130135
#
# [22 rows x 22 columns]

# %%
num_col.corr(method='pearson')
# Out:
#                          EmployeeID       Age  Attrition  DistanceFromHome  \
# EmployeeID                 1.000000  0.008649  -0.004729         -0.001097
# Age                        0.008649  1.000000  -0.159205          0.006963
# Attrition                 -0.004729 -0.159205   1.000000         -0.009730
# DistanceFromHome          -0.001097  0.006963  -0.009730          1.000000
# Education                 -0.009680 -0.035706  -0.015111         -0.008638
# EmployeeCount                   NaN       NaN        NaN               NaN
# JobLevel                  -0.003303 -0.002884  -0.010290         -0.037329
# MonthlyIncome              0.007338 -0.044314  -0.031176         -0.021607
# NumCompaniesWorked         0.000144  0.299297   0.041503         -0.012617
# PercentSalaryHike         -0.004456 -0.033137   0.032533          0.038125
# StandardHours                   NaN       NaN        NaN               NaN
# StockOptionLevel          -0.014254 -0.031753  -0.006839          0.011169
# TotalWorkingYears         -0.000139  0.678436  -0.170238          0.008925
# TrainingTimesLastYear     -0.010191 -0.027308  -0.049431         -0.009001
# YearsAtCompany             0.004086  0.311309  -0.134392          0.031684
# YearsSinceLastPromotion    0.000256  0.216513  -0.033019          0.002290
# YearsWithCurrManager       0.008579  0.202089  -0.156199          0.021584
# EnvironmentSatisfaction    0.004072  0.013505  -0.101517          0.019682
# JobSatisfaction           -0.001298 -0.003800  -0.097982         -0.010018
# WorkLifeBalance            0.003263 -0.027059  -0.053965          0.003694
# JobInvolvement             0.008591  0.018196  -0.015588         -0.001837
# PerformanceRating         -0.006892 -0.025563   0.023403          0.036418
#
#                          Education  EmployeeCount  JobLevel  MonthlyIncome  \
# EmployeeID               -0.009680            NaN -0.003303       0.007338
# Age                      -0.035706            NaN -0.002884      -0.044314
# Attrition                -0.015111            NaN -0.010290      -0.031176
# DistanceFromHome         -0.008638            NaN -0.037329      -0.021607
# Education                 1.000000            NaN  0.045746       0.006410
# EmployeeCount                  NaN            NaN       NaN            NaN
# JobLevel                  0.045746            NaN  1.000000       0.047316
# MonthlyIncome             0.006410            NaN  0.047316       1.000000
# NumCompaniesWorked       -0.016096            NaN -0.010877      -0.019915
# PercentSalaryHike        -0.040531            NaN  0.010973       0.004325
# StandardHours                  NaN            NaN       NaN            NaN
# StockOptionLevel          0.001261            NaN  0.000993       0.026930
# TotalWorkingYears        -0.011581            NaN -0.035498      -0.033694
# TrainingTimesLastYear     0.010472            NaN -0.032500       0.050112
# YearsAtCompany            0.006080            NaN -0.064219       0.000995
# YearsSinceLastPromotion   0.022490            NaN -0.060811       0.065219
# YearsWithCurrManager      0.005358            NaN -0.055251       0.024304
# EnvironmentSatisfaction  -0.041370            NaN -0.022682      -0.008128
# JobSatisfaction           0.000377            NaN -0.014328       0.008336
# WorkLifeBalance          -0.014433            NaN -0.023290       0.001666
# JobInvolvement           -0.018279            NaN -0.012630       0.023346
# PerformanceRating        -0.035591            NaN -0.002474       0.016093
#
#                          NumCompaniesWorked  PercentSalaryHike  ...  \
# EmployeeID                         0.000144          -0.004456  ...
# Age                                0.299297          -0.033137  ...
# Attrition                          0.041503           0.032533  ...
# DistanceFromHome                  -0.012617           0.038125  ...
# Education                         -0.016096          -0.040531  ...
# EmployeeCount                           NaN                NaN  ...
# JobLevel                          -0.010877           0.010973  ...
# MonthlyIncome                     -0.019915           0.004325  ...
# NumCompaniesWorked                 1.000000           0.031683  ...
# PercentSalaryHike                  0.031683           1.000000  ...
# StandardHours                           NaN                NaN  ...
# StockOptionLevel                   0.017685           0.012548  ...
# TotalWorkingYears                  0.237472          -0.019495  ...
# TrainingTimesLastYear             -0.032123          -0.037392  ...
# YearsAtCompany                    -0.116322          -0.029707  ...
# YearsSinceLastPromotion           -0.035421          -0.029542  ...
# YearsWithCurrManager              -0.108223          -0.040864  ...
# EnvironmentSatisfaction            0.010418           0.000708  ...
# JobSatisfaction                   -0.056929           0.031580  ...
# WorkLifeBalance                   -0.005642          -0.038908  ...
# JobInvolvement                     0.028150          -0.004658  ...
# PerformanceRating                  0.019059           0.773550  ...
#
#                          TotalWorkingYears  TrainingTimesLastYear  \
# EmployeeID                       -0.000139              -0.010191
# Age                               0.678436              -0.027308
# Attrition                        -0.170238              -0.049431
# DistanceFromHome                  0.008925              -0.009001
# Education                        -0.011581               0.010472
# EmployeeCount                          NaN                    NaN
# JobLevel                         -0.035498              -0.032500
# MonthlyIncome                    -0.033694               0.050112
# NumCompaniesWorked                0.237472              -0.032123
# PercentSalaryHike                -0.019495              -0.037392
# StandardHours                          NaN                    NaN
# StockOptionLevel                  0.003128              -0.069902
# TotalWorkingYears                 1.000000              -0.041842
# TrainingTimesLastYear            -0.041842               1.000000
# YearsAtCompany                    0.624468              -0.007894
# YearsSinceLastPromotion           0.403405               0.016121
# YearsWithCurrManager              0.457363              -0.013270
# EnvironmentSatisfaction          -0.000245               0.018526
# JobSatisfaction                  -0.018949              -0.020764
# WorkLifeBalance                  -0.001430              -0.024271
# JobInvolvement                    0.007406              -0.010144
# PerformanceRating                -0.001952              -0.022895
#
#                          YearsAtCompany  YearsSinceLastPromotion  \
# EmployeeID                     0.004086                 0.000256
# Age                            0.311309                 0.216513
# Attrition                     -0.134392                -0.033019
# DistanceFromHome               0.031684                 0.002290
# Education                      0.006080                 0.022490
# EmployeeCount                       NaN                      NaN
# JobLevel                      -0.064219                -0.060811
# MonthlyIncome                  0.000995                 0.065219
# NumCompaniesWorked            -0.116322                -0.035421
# PercentSalaryHike             -0.029707                -0.029542
# StandardHours                       NaN                      NaN
# StockOptionLevel               0.007886                 0.019063
# TotalWorkingYears              0.624468                 0.403405
# TrainingTimesLastYear         -0.007894                 0.016121
# YearsAtCompany                 1.000000                 0.618409
# YearsSinceLastPromotion        0.618409                 1.000000
# YearsWithCurrManager           0.769212                 0.510224
# EnvironmentSatisfaction        0.003524                 0.015979
# JobSatisfaction               -0.002751                -0.017048
# WorkLifeBalance                0.017247                 0.006609
# JobInvolvement                 0.008314                 0.025395
# PerformanceRating             -0.011038                -0.020159
#
#                          YearsWithCurrManager  EnvironmentSatisfaction  \
# EmployeeID                           0.008579                 0.004072
# Age                                  0.202089                 0.013505
# Attrition                           -0.156199                -0.101517
# DistanceFromHome                     0.021584                 0.019682
# Education                            0.005358                -0.041370
# EmployeeCount                             NaN                      NaN
# JobLevel                            -0.055251                -0.022682
# MonthlyIncome                        0.024304                -0.008128
# NumCompaniesWorked                  -0.108223                 0.010418
# PercentSalaryHike                   -0.040864                 0.000708
# StandardHours                             NaN                      NaN
# StockOptionLevel                     0.017757                -0.001988
# TotalWorkingYears                    0.457363                -0.000245
# TrainingTimesLastYear               -0.013270                 0.018526
# YearsAtCompany                       0.769212                 0.003524
# YearsSinceLastPromotion              0.510224                 0.015979
# YearsWithCurrManager                 1.000000                -0.003873
# EnvironmentSatisfaction             -0.003873                 1.000000
# JobSatisfaction                     -0.023043                -0.011142
# WorkLifeBalance                      0.007603                 0.026073
# JobInvolvement                      -0.001372                 0.014500
# PerformanceRating                   -0.009426                 0.013534
#
#                          JobSatisfaction  WorkLifeBalance  JobInvolvement  \
# EmployeeID                     -0.001298         0.003263        0.008591
# Age                            -0.003800        -0.027059        0.018196
# Attrition                      -0.097982        -0.053965       -0.015588
# DistanceFromHome               -0.010018         0.003694       -0.001837
# Education                       0.000377        -0.014433       -0.018279
# EmployeeCount                        NaN              NaN             NaN
# JobLevel                       -0.014328        -0.023290       -0.012630
# MonthlyIncome                   0.008336         0.001666        0.023346
# NumCompaniesWorked             -0.056929        -0.005642        0.028150
# PercentSalaryHike               0.031580        -0.038908       -0.004658
# StandardHours                        NaN              NaN             NaN
# StockOptionLevel                0.039850        -0.022238        0.010295
# TotalWorkingYears              -0.018949        -0.001430        0.007406
# TrainingTimesLastYear          -0.020764        -0.024271       -0.010144
# YearsAtCompany                 -0.002751         0.017247        0.008314
# YearsSinceLastPromotion        -0.017048         0.006609        0.025395
# YearsWithCurrManager           -0.023043         0.007603       -0.001372
# EnvironmentSatisfaction        -0.011142         0.026073        0.014500
# JobSatisfaction                 1.000000        -0.022518        0.004466
# WorkLifeBalance                -0.022518         1.000000       -0.027901
# JobInvolvement                  0.004466        -0.027901        1.000000
# PerformanceRating               0.042691        -0.021953        0.010699
#
#                          PerformanceRating
# EmployeeID                       -0.006892
# Age                              -0.025563
# Attrition                         0.023403
# DistanceFromHome                  0.036418
# Education                        -0.035591
# EmployeeCount                          NaN
# JobLevel                         -0.002474
# MonthlyIncome                     0.016093
# NumCompaniesWorked                0.019059
# PercentSalaryHike                 0.773550
# StandardHours                          NaN
# StockOptionLevel                 -0.036348
# TotalWorkingYears                -0.001952
# TrainingTimesLastYear            -0.022895
# YearsAtCompany                   -0.011038
# YearsSinceLastPromotion          -0.020159
# YearsWithCurrManager             -0.009426
# EnvironmentSatisfaction           0.013534
# JobSatisfaction                   0.042691
# WorkLifeBalance                  -0.021953
# JobInvolvement                    0.010699
# PerformanceRating                 1.000000
#
# [22 rows x 22 columns]

# %%
sns.heatmap(num_col.corr())               ###heatmap
plt.show()

# %%
plt.figure(figsize = (14,14))
sns.heatmap(num_col.corr(), annot=True)               ###heatmap
plt.show()
